# %% [markdown]
# ## Korak 1:
# (Ucitavanje OpenCV biblioteka i ucitavanje zadate slike)

# %%
import cv2
import sys

import matplotlib.pyplot as plt
# %matplotlib inline

imagePath = 'orginal_image.jpg'
cascPath = 'haarcascade_frontalface_default.xml'

faceCascade = cv2.CascadeClassifier(cascPath)
image = cv2.imread(imagePath)

plt.imshow(image)
plt.title("Orginal image")
plt.show()

# %% [markdown]
# ##  Korak 2:
# (Ucitavanje broja detektovanih lica na zadatoj slici)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30),
    flags = cv2.CASCADE_SCALE_IMAGE
)

print("Found {0} faces!".format(len(faces)))
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
# Out:
# Found 3 faces!

# %% [markdown]
# ## Korak 3:
# (Ucitavanje zadate slike i ucitavanje detektovanih lica na zadatoj slici )

# %%
plt.imshow(image)
plt.title("Orginal image")
plt.show()
